# %% [markdown]
# # Student Performance Analysis using Pandas
#
# ## Objective
#
# Analyze student performance data using Pandas to answer real-world analytical questions.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('student_performance.csv')
df
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 749622      749623                     17.6                   72.7
# 749623      749624                     12.7                   84.8
# 749624      749625                     15.6                   97.2
# 749625      749626                     22.7                   75.8
# 749626      749627                     13.8                    NaN
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# 2                       5.3        100.0     A
# 3                       7.0        100.0     A
# 4                       6.9         92.0     A
# ...                     ...          ...   ...
# 749622                  4.8         90.8     A
# 749623                  6.4         73.0     B
# 749624                  6.1        100.0     A
# 749625                  5.3        100.0     A
# 749626                  NaN          NaN   NaN
#
# [749627 rows x 6 columns]

# %% [markdown]
# ### How many rows and columns are there in the dataset?

# %%
df.shape
# Out:
# (749627, 6)

# %% [markdown]
# ### Show the first 10 rows of the dataset.

# %%
df.head(10)
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
# 5           6                     13.4                   65.1
# 6           7                     26.1                   81.8
# 7           8                     20.4                  100.0
# 8           9                     11.7                  100.0
# 9          10                     18.8                   67.6
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A
# 5                  5.0         97.5     A
# 6                  5.9        100.0     A
# 7                  4.0         96.1     A
# 8                  8.2         69.8     C
# 9                  6.0         80.3     B

# %% [markdown]
# ### Show the last 10 rows of the dataset.

# %%
df.tail(10)
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 749617      749618                     12.2                   83.0
# 749618      749619                      5.8                   84.9
# 749619      749620                     21.6                   87.5
# 749620      749621                      2.9                   84.8
# 749621      749622                     14.6                   90.3
# 749622      749623                     17.6                   72.7
# 749623      749624                     12.7                   84.8
# 749624      749625                     15.6                   97.2
# 749625      749626                     22.7                   75.8
# 749626      749627                     13.8                    NaN
#
#         class_participation  total_score grade
# 749617                  6.8         76.9     B
# 749618                  5.5         70.2     B
# 749619                  6.7         94.1     A
# 749620                  9.9         66.3     C
# 749621                  3.5         78.0     B
# 749622                  4.8         90.8     A
# 749623                  6.4         73.0     B
# 749624                  6.1        100.0     A
# 749625                  5.3        100.0     A
# 749626                  NaN          NaN   NaN

# %% [markdown]
# ### What are the column names in the dataset?

# %%
df.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %% [markdown]
# ### What is the maximum value of weekly_self_study_hours?

# %%
df['weekly_self_study_hours'].max()
# Out:
# 40.0

# %% [markdown]
# ### Which student studied the most hours in a week?

# %%
df.loc[df['weekly_self_study_hours'].max()]
# Out:
# student_id                    41
# weekly_self_study_hours     20.2
# attendance_percentage       85.6
# class_participation          5.6
# total_score                100.0
# grade                          A
# Name: 40, dtype: object

# %% [markdown]
# ### Show the top 5 students by weekly_self_study_hours.

# %%
df.sort_values('weekly_self_study_hours',ascending=False).head(5)
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 494825      494826                     40.0                   86.3
# 428200      428201                     40.0                   81.1
# 157322      157323                     40.0                   78.5
# 190334      190335                     40.0                   80.6
# 449084      449085                     40.0                  100.0
#
#         class_participation  total_score grade
# 494825                  2.9        100.0     A
# 428200                  5.6        100.0     A
# 157322                  3.3        100.0     A
# 190334                  5.9        100.0     A
# 449084                  6.6        100.0     A

# %% [markdown]
# ### Which student has the highest attendance percentage?

# %%
df[df['attendance_percentage'] == df['attendance_percentage'].max()]
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 7                8                     20.4                  100.0
# 8                9                     11.7                  100.0
# 18              19                      8.6                  100.0
# 22              23                     15.5                  100.0
# 44              45                      4.7                  100.0
# ...            ...                      ...                    ...
# 749517      749518                      7.3                  100.0
# 749530      749531                     20.0                  100.0
# 749552      749553                      6.0                  100.0
# 749584      749585                     12.0                  100.0
# 749592      749593                     13.2                  100.0
#
#         class_participation  total_score grade
# 7                       4.0         96.1     A
# 8                       8.2         69.8     C
# 18                      9.0         75.4     B
# 22                      8.5         76.3     B
# 44                      3.3         55.9     C
# ...                     ...          ...   ...
# 749517                  2.2         57.6     C
# 749530                  8.4         98.7     A
# 749552                  3.5         64.3     C
# 749584                  6.7         74.4     B
# 749592                  8.8         74.3     B
#
# [50665 rows x 6 columns]

# %% [markdown]
# ### Which student has the highest class participation?

# %%
df[df['class_participation']==df['class_participation'].max()]
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 137            138                     12.7                   78.3
# 148            149                     18.7                   92.8
# 159            160                     19.6                   78.5
# 221            222                      1.9                   78.8
# 228            229                     10.0                   65.7
# ...            ...                      ...                    ...
# 749488      749489                      8.2                   72.6
# 749490      749491                      7.7                   93.3
# 749506      749507                     11.5                   98.5
# 749519      749520                     19.4                   96.8
# 749573      749574                      6.2                   86.4
#
#         class_participation  total_score grade
# 137                    10.0         78.7     B
# 148                    10.0        100.0     A
# 159                    10.0         93.2     A
# 221                    10.0         46.4     D
# 228                    10.0         69.5     C
# ...                     ...          ...   ...
# 749488                 10.0         85.1     A
# 749490                 10.0         68.4     C
# 749506                 10.0         73.7     B
# 749519                 10.0         94.1     A
# 749573                 10.0         63.4     C
#
# [18078 rows x 6 columns]

# %% [markdown]
# ### Create a new column score_level
# "High" if total_score ≥ 90 , "Medium" if 70 ≤ total_score < 90, "Low" if total_score < 70

# %%
def score_level(x):
    if x >= 90:
        return 'High'
    elif 70 <= x < 90:
        return 'Medium'
    else:
        return 'Low'

# %%
df['score_level'] = df['total_score'].apply(score_level)
df
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 749622      749623                     17.6                   72.7
# 749623      749624                     12.7                   84.8
# 749624      749625                     15.6                   97.2
# 749625      749626                     22.7                   75.8
# 749626      749627                     13.8                    NaN
#
#         class_participation  total_score grade score_level
# 0                       3.8         97.9     A        High
# 1                       2.5         83.9     B      Medium
# 2                       5.3        100.0     A        High
# 3                       7.0        100.0     A        High
# 4                       6.9         92.0     A        High
# ...                     ...          ...   ...         ...
# 749622                  4.8         90.8     A        High
# 749623                  6.4         73.0     B      Medium
# 749624                  6.1        100.0     A        High
# 749625                  5.3        100.0     A        High
# 749626                  NaN          NaN   NaN         Low
#
# [749627 rows x 7 columns]

# %% [markdown]
# ### Which student has the highest total_score?

# %%
df[df['total_score']==df['total_score'].max()]
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 6                7                     26.1                   81.8
# 17              18                     17.2                   74.0
# 20              21                     25.3                   89.3
# ...            ...                      ...                    ...
# 749606      749607                     21.6                   88.3
# 749610      749611                     24.8                   79.6
# 749616      749617                     12.8                   78.5
# 749624      749625                     15.6                   97.2
# 749625      749626                     22.7                   75.8
#
#         class_participation  total_score grade score_level
# 2                       5.3        100.0     A        High
# 3                       7.0        100.0     A        High
# 6                       5.9        100.0     A        High
# 17                      8.1        100.0     A        High
# 20                      6.4        100.0     A        High
# ...                     ...          ...   ...         ...
# 749606                  6.3        100.0     A        High
# 749610                  4.3        100.0     A        High
# 749616                  1.5        100.0     A        High
# 749624                  6.1        100.0     A        High
# 749625                  5.3        100.0     A        High
#
# [201261 rows x 7 columns]

# %% [markdown]
# ### How many students scored exactly 100 in total_score?

# %%
df[df['total_score']==df['total_score'].max()].count()['student_id']
# Out:
# np.int64(201261)

# %%
len(df[df['total_score']==df['total_score'].max()])
# Out:
# 201261

# %% [markdown]
# ### Make a new column for study efficiency = total_score ÷ weekly_self_study_hours.

# %%
df['study_efficiency']= df['total_score']/df['weekly_self_study_hours']  # that's called broadcasting

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade score_level  study_efficiency
# 0                  3.8         97.9     A        High          5.291892
# 1                  2.5         83.9     B      Medium          5.992857
# 2                  5.3        100.0     A        High          5.128205
# 3                  7.0        100.0     A        High          3.891051
# 4                  6.9         92.0     A        High          6.865672

# %% [markdown]
# ### Create a new column study_category
# "Light" if weekly_self_study_hours < 10,
# "Moderate" if 10 ≤ hours ≤ 20,
# "Heavy" if hours > 20

# %%
def category(x):
  if x<10:
    return 'Light'
  elif 10<= x <=20:
    return 'Moderate'
  else:
    return 'Heavy'

# %%
df['study_category'] = df['weekly_self_study_hours'].apply(category)

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade score_level  study_efficiency  \
# 0                  3.8         97.9     A        High          5.291892
# 1                  2.5         83.9     B      Medium          5.992857
# 2                  5.3        100.0     A        High          5.128205
# 3                  7.0        100.0     A        High          3.891051
# 4                  6.9         92.0     A        High          6.865672
#
#   study_category
# 0       Moderate
# 1       Moderate
# 2       Moderate
# 3          Heavy
# 4       Moderate
